# %%
import pandas as pd
df=pd.read_csv('/content/WorldCups.csv')

# %%
df
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Winner', 'Runners-Up', 'Third', 'Fourth',
#        'GoalsScored', 'QualifiedTeams', 'MatchesPlayed', 'Attendance'],
#       dtype='object')

# %% [markdown]
# # Brazil Champion

# %%
df[df['Winner']== 'Brazil']
# Out:
#     Year      Country  Winner      Runners-Up       Third          Fourth  \
# 5   1958       Sweden  Brazil          Sweden      France      Germany FR
# 6   1962        Chile  Brazil  Czechoslovakia       Chile      Yugoslavia
# 8   1970       Mexico  Brazil           Italy  Germany FR         Uruguay
# 14  1994          USA  Brazil           Italy      Sweden        Bulgaria
# 16  2002  Korea/Japan  Brazil         Germany      Turkey  Korea Republic
#
#     GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 5           126              16             35    819.810
# 6            89              16             32    893.172
# 8            95              16             32  1.603.975
# 14          141              24             52  3.587.538
# 16          161              32             64  2.705.197

# %% [markdown]
# # Argentina Champion

# %%
df[df['Winner']== 'Argentina']
# Out:
#     Year    Country     Winner   Runners-Up   Third   Fourth  GoalsScored  \
# 10  1978  Argentina  Argentina  Netherlands  Brazil    Italy          102
# 12  1986     Mexico  Argentina   Germany FR  France  Belgium          132
#
#     QualifiedTeams  MatchesPlayed Attendance
# 10              16             38  1.545.791
# 12              24             52  2.394.031

# %% [markdown]
# # Brazil  Runners-Up

# %%
df[df['Runners-Up']== 'Brazil']
# Out:
#     Year Country   Winner Runners-Up    Third       Fourth  GoalsScored  \
# 3   1950  Brazil  Uruguay     Brazil   Sweden        Spain           88
# 15  1998  France   France     Brazil  Croatia  Netherlands          171
#
#     QualifiedTeams  MatchesPlayed Attendance
# 3               13             22  1.045.246
# 15              32             64  2.785.100

# %% [markdown]
# # Argentina Runners-Up

# %%
condition=df['Runners-Up']== 'Argentina'
df[condition]
# Out:
#     Year  Country      Winner Runners-Up        Third      Fourth  \
# 0   1930  Uruguay     Uruguay  Argentina          USA  Yugoslavia
# 13  1990    Italy  Germany FR  Argentina        Italy     England
# 19  2014   Brazil     Germany  Argentina  Netherlands      Brazil
#
#     GoalsScored  QualifiedTeams  MatchesPlayed Attendance  goalperMatch
# 0            70              13             18    590.549      3.888889
# 13          115              24             52  2.516.215      2.211538
# 19          171              32             64  3.386.810      2.671875

# %%
df.sort_values('GoalsScored')
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 7   1966       England     England      Germany FR     Portugal
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 13  1990         Italy  Germany FR       Argentina        Italy
# 5   1958        Sweden      Brazil          Sweden       France
# 12  1986        Mexico   Argentina      Germany FR       France
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 14  1994           USA      Brazil           Italy       Sweden
# ...

# %%
df['goalperMatch']= df.GoalsScored/df.MatchesPlayed

# %%
df.goalperMatch

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.Attendance)
# Out:
# pandas.core.series.Series

# %%
s=df['Attendance'].sum()
s
# Out:
# '590.549363.000375.7001.045.246768.607819.810893.1721.563.1351.603.9751.865.7531.545.7912.109.7232.394.0312.516.2153.587.5382.785.1002.705.1973.359.4393.178.8563.386.810'

# %%
df['Attendance'].max()
# Out:
# '893.172'

# %%
df['GoalsScored'].max()
# Out:
# 171

# %%
df.sort_values('Year')
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
df.columns[0]
# Out:
# 'Year'

# %%
df.columns[0:2]
# Out:
# Index(['Year', 'Country'], dtype='object')

# %%
#df[condition]

df[df['Country']== 'Argentina']
# Out:
#     Year    Country     Winner   Runners-Up   Third Fourth  GoalsScored  \
# 10  1978  Argentina  Argentina  Netherlands  Brazil  Italy          102
#
#     QualifiedTeams  MatchesPlayed Attendance  goalperMatch
# 10              16             38  1.545.791      2.684211

# %%
condition=df['Runners-Up']== 'Argentina'
df[condition]
# Out:
#     Year  Country      Winner Runners-Up        Third      Fourth  \
# 0   1930  Uruguay     Uruguay  Argentina          USA  Yugoslavia
# 13  1990    Italy  Germany FR  Argentina        Italy     England
# 19  2014   Brazil     Germany  Argentina  Netherlands      Brazil
#
#     GoalsScored  QualifiedTeams  MatchesPlayed Attendance  goalperMatch
# 0            70              13             18    590.549      3.888889
# 13          115              24             52  2.516.215      2.211538
# 19          171              32             64  3.386.810      2.671875
